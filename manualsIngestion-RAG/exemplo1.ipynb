# %%
#Importar o cliente do Qdrant
from qdrant_client import QdrantClient

#Criar nossa coleção
from qdrant_client.http.models import Distance, VectorParams

#Criar nossos vetores
from qdrant_client.http.models import PointStruct

#filtrar payloads
from qdrant_client.http.models import Filter, FieldCondition, MatchValue

#Pretty printer
from pprint import pprint

# %%
client = QdrantClient(host="localhost", port=6333)

# %%
client.create_collection(
    collection_name="test_collection",
    vectors_config=VectorParams(size=4, distance=Distance.DOT)
)
# Out:
# True

# %%
operation_info = client.upsert(
    collection_name="test_collection",
    points=[
        PointStruct(id=1, vector=[0.05, 0.61, 0.76, 0.74], payload={"continente": "Europa", "cidade": "Berlin"}),
        PointStruct(id=2, vector=[0.19, 0.81, 0.75, 0.11], payload={"continente": "Europa", "cidade": "Londres"}),
        PointStruct(id=4, vector=[0.18, 0.01, 0.85, 0.80], payload={"continente": "America", "cidade": "Nova York"}),
        PointStruct(id=5, vector=[0.24, 0.18, 0.22, 0.44], payload={"continente": "Asia", "cidade": "Beijing"}),
        PointStruct(id=6, vector=[0.35, 0.08, 0.11, 0.44], payload={"continente": "Asia", "cidade": "Mumbai"}),
    ]
)
pprint(operation_info)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
search_result = client.query_points(
    collection_name="test_collection",
    query=[0.2, 0.1, 0.9, 0.7],
    limit=3
)

pprint(search_result)
# Out:
# QueryResponse(points=[ScoredPoint(id=4, version=1, score=1.362, payload={'continente': 'America', 'cidade': 'Nova York'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=1, version=1, score=1.273, payload={'continente': 'Europa', 'cidade': 'Berlin'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=2, version=1, score=0.871, payload={'continente': 'Europa', 'cidade': 'Londres'}, vector=None, shard_key=None, order_value=None)])

# %%
search_result = client.query_points(
    collection_name="test_collection",
    query=[0.2, 0.1, 0.9, 0.7],
    limit=3,
    query_filter= Filter(
        must=[
            FieldCondition(
                key="continente",
                match=MatchValue(value="Asia")
            )
        ]
    ),
    with_payload=True
)

pprint(search_result)
# Out:
#   Cell In[15], line 5
#     query_filter=filter= Filter(
#                        ^
# SyntaxError: invalid syntax
